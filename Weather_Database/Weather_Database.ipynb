# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | egvekinot
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | aguilas
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | khalilabad
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | fare
# Processing Record 12 of Set 1 | hovd
# Processing Record 13 of Set 1 | leh
# Processing Record 14 of Set 1 | guantanamo
# Processing Record 15 of Set 1 | zhezkazgan
# Processing Record 16 of Set 1 | aloleng
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | fukuma
# Processing Record 19 of Set 1 | ngunguru
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | ranong
# Processing Record 25 of Set 1 | bonthe
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | lazaro cardenas
# Processing Record 28 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 1 | xining
# Processing Record 30 of Set 1 | middlebury
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | khorramshahr
# Processing Record 34 of Set 1 | general roca
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | lucea
# Processing Record 37 of Set 1 | vao
# Processing Record 38 of Set 1 | the valley
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | leningradskiy
# Processing Record 41 of Set 1 | guerrero negro
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | aykhal
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | koshurnikovo
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | kutum
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | san patricio
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 2 | namatanai
# Processing Record 10 of Set 2 | aksu
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | kruisfontein
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | iqaluit
# Processing Record 15 of Set 2 | puntarenas
# Processing Record 16 of Set 2 | susehri
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | sajanan
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | kulhudhuffushi
# Processing Record 24 of Set 2 | klaeng
# Processing Record 25 of Set 2 | tateyama
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | gedo
# Processing Record 28 of Set 2 | okha
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | itarema
# Processing Record 32 of Set 2 | marawi
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | aligudarz
# Processing Record 36 of Set 2 | lambarene
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | tura
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | mongomo
# Processing Record 42 of Set 2 | araceli
# Processing Record 43 of Set 2 | erie
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 2 | najran
# Processing Record 46 of Set 2 | michigan city
# Processing Record 47 of Set 2 | minapasuk
# Processing Record 48 of Set 2 | port blair
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | vanimo
# Processing Record 1 of Set 3 | qaqortoq
# Processing Record 2 of Set 3 | fort nelson
# Processing Record 3 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 3 | biloela
# Processing Record 5 of Set 3 | husavik
# Processing Record 6 of Set 3 | labuhan
# Processing Record 7 of Set 3 | chernyshevskiy
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | hofn
# Processing Record 12 of Set 3 | misratah
# Processing Record 13 of Set 3 | kabinda
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | solano
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | ulaangom
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | kloulklubed
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | touros
# Processing Record 24 of Set 3 | eresos
# Processing Record 25 of Set 3 | vila velha
# Processing Record 26 of Set 3 | haines junction
# Processing Record 27 of Set 3 | richards bay
# Processing Record 28 of Set 3 | asfi
# Processing Record 29 of Set 3 | morondava
# Processing Record 30 of Set 3 | rabo de peixe
# Processing Record 31 of Set 3 | machiques
# Processing Record 32 of Set 3 | voyvozh
# Processing Record 33 of Set 3 | abha
# Processing Record 34 of Set 3 | fukue
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | naze
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | balcani
# Processing Record 40 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 3 | yen bai
# Processing Record 42 of Set 3 | oussouye
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | yumen
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | atbasar
# Processing Record 50 of Set 3 | glenluce
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | gorin
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | la ronge
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | iranshahr
# Processing Record 7 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 4 | christchurch
# Processing Record 9 of Set 4 | bubaque
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | longyearbyen
# Processing Record 12 of Set 4 | ibicarai
# Processing Record 13 of Set 4 | lithakia
# Processing Record 14 of Set 4 | iquitos
# Processing Record 15 of Set 4 | waingapu
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | shingu
# Processing Record 18 of Set 4 | okhotsk
# Processing Record 19 of Set 4 | artyom
# Processing Record 20 of Set 4 | savonlinna
# Processing Record 21 of Set 4 | bombay
# Processing Record 22 of Set 4 | davila
# Processing Record 23 of Set 4 | palora
# Processing Record 24 of Set 4 | kresek
# Processing Record 25 of Set 4 | prince rupert
# Processing Record 26 of Set 4 | portland
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | kostomuksha
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | prainha
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | cap malheureux
# Processing Record 34 of Set 4 | rudbar
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | marsa matruh
# Processing Record 37 of Set 4 | lappeenranta
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | resistencia
# Processing Record 42 of Set 4 | ismailia
# Processing Record 43 of Set 4 | isangel
# Processing Record 44 of Set 4 | ugoofaaru
# Processing Record 45 of Set 4 | quepos
# Processing Record 46 of Set 4 | nuuk
# Processing Record 47 of Set 4 | charagua
# Processing Record 48 of Set 4 | obihiro
# Processing Record 49 of Set 4 | verkhnyaya inta
# Processing Record 50 of Set 4 | pacific grove
# Processing Record 1 of Set 5 | oranjemund
# Processing Record 2 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 5 | honningsvag
# Processing Record 4 of Set 5 | isparta
# Processing Record 5 of Set 5 | faanui
# Processing Record 6 of Set 5 | nemuro
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | severo-kurilsk
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | lianzhou
# Processing Record 12 of Set 5 | castro
# Processing Record 13 of Set 5 | acarau
# Processing Record 14 of Set 5 | keflavik
# Processing Record 15 of Set 5 | zaria
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | plettenberg bay
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | san quintin
# Processing Record 20 of Set 5 | baley
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | vila
# Processing Record 23 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 5 | longhua
# Processing Record 25 of Set 5 | eydhafushi
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | vila franca do campo
# Processing Record 29 of Set 5 | meadow lake
# Processing Record 30 of Set 5 | liverpool
# Processing Record 31 of Set 5 | andenes
# Processing Record 32 of Set 5 | sal rei
# Processing Record 33 of Set 5 | belyy yar
# Processing Record 34 of Set 5 | dedovichi
# Processing Record 35 of Set 5 | kapit
# Processing Record 36 of Set 5 | cascais
# Processing Record 37 of Set 5 | atasu
# Processing Record 38 of Set 5 | bulnes
# Processing Record 39 of Set 5 | wexford
# Processing Record 40 of Set 5 | rockport
# Processing Record 41 of Set 5 | jalingo
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 44 of Set 5 | yerbogachen
# Processing Record 45 of Set 5 | beian
# Processing Record 46 of Set 5 | svetlaya
# Processing Record 47 of Set 5 | marquette
# Processing Record 48 of Set 5 | fortuna
# Processing Record 49 of Set 5 | hami
# Processing Record 50 of Set 5 | galesong
# Processing Record 1 of Set 6 | gornozavodsk
# Processing Record 2 of Set 6 | houma
# Processing Record 3 of Set 6 | calvinia
# Processing Record 4 of Set 6 | kirakira
# Processing Record 5 of Set 6 | johnstown
# Processing Record 6 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 7 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 8 of Set 6 | jieshi
# Processing Record 9 of Set 6 | beruwala
# Processing Record 10 of Set 6 | komsomolskiy
# Processing Record 11 of Set 6 | suntar
# Processing Record 12 of Set 6 | rio claro
# Processing Record 13 of Set 6 | mangai
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | neya
# Processing Record 16 of Set 6 | sept-iles
# Processing Record 17 of Set 6 | manicore
# Processing Record 18 of Set 6 | maldonado
# Processing Record 19 of Set 6 | sangar
# Processing Record 20 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 6 | kupino
# Processing Record 22 of Set 6 | bilibino
# Processing Record 23 of Set 6 | honiara
# Processing Record 24 of Set 6 | port-gentil
# Processing Record 25 of Set 6 | pavelets
# Processing Record 26 of Set 6 | sistranda
# Processing Record 27 of Set 6 | axim
# Processing Record 28 of Set 6 | nagapattinam
# Processing Record 29 of Set 6 | vinkovci
# Processing Record 30 of Set 6 | arraial do cabo
# Processing Record 31 of Set 6 | okato
# Processing Record 32 of Set 6 | lata
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | pemangkat
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | pundaguitan
# Processing Record 38 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 6 | byron bay
# Processing Record 40 of Set 6 | cah ab
# City not found. Skipping...
# Processing Record 41 of Set 6 | ust-karsk
# Processing Record 42 of Set 6 | makat
# Processing Record 43 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | dikson
# Processing Record 45 of Set 6 | owo
# Processing Record 46 of Set 6 | colonia
# Processing Record 47 of Set 6 | vidim
# Processing Record 48 of Set 6 | grand baie
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 50 of Set 6 | kenai
# Processing Record 1 of Set 7 | sao raimundo nonato
# Processing Record 2 of Set 7 | havre-saint-pierre
# Processing Record 3 of Set 7 | burica
# City not found. Skipping...
# Processing Record 4 of Set 7 | bandarbeyla
# Processing Record 5 of Set 7 | kuusamo
# Processing Record 6 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 7 | yulara
# Processing Record 8 of Set 7 | nome
# Processing Record 9 of Set 7 | kaitangata
# Processing Record 10 of Set 7 | graaff-reinet
# Processing Record 11 of Set 7 | kalabo
# Processing Record 12 of Set 7 | talnakh
# Processing Record 13 of Set 7 | juneau
# Processing Record 14 of Set 7 | port macquarie
# Processing Record 15 of Set 7 | todos santos
# Processing Record 16 of Set 7 | maymyo
# Processing Record 17 of Set 7 | luanda
# Processing Record 18 of Set 7 | urucara
# Processing Record 19 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 7 | tilichiki
# Processing Record 23 of Set 7 | parintins
# Processing Record 24 of Set 7 | kusti
# Processing Record 25 of Set 7 | kaeo
# Processing Record 26 of Set 7 | puri
# Processing Record 27 of Set 7 | payson
# Processing Record 28 of Set 7 | luba
# Processing Record 29 of Set 7 | onega
# Processing Record 30 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 7 | shu
# Processing Record 32 of Set 7 | abay
# Processing Record 33 of Set 7 | jalu
# Processing Record 34 of Set 7 | cherskiy
# Processing Record 35 of Set 7 | halifax
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | sawakin
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | ihosy
# Processing Record 40 of Set 7 | cabadiangan
# Processing Record 41 of Set 7 | ogori
# Processing Record 42 of Set 7 | surt
# Processing Record 43 of Set 7 | lubao
# Processing Record 44 of Set 7 | atambua
# Processing Record 45 of Set 7 | nampula
# Processing Record 46 of Set 7 | atyrau
# Processing Record 47 of Set 7 | omsukchan
# Processing Record 48 of Set 7 | hualmay
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | akdepe
# Processing Record 1 of Set 8 | arman
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | kattivakkam
# Processing Record 4 of Set 8 | jacareacanga
# Processing Record 5 of Set 8 | omboue
# Processing Record 6 of Set 8 | batagay-alyta
# Processing Record 7 of Set 8 | moussoro
# Processing Record 8 of Set 8 | kirkuk
# Processing Record 9 of Set 8 | valkeala
# Processing Record 10 of Set 8 | nanortalik
# Processing Record 11 of Set 8 | talara
# Processing Record 12 of Set 8 | areal
# Processing Record 13 of Set 8 | pendencias
# Processing Record 14 of Set 8 | necochea
# Processing Record 15 of Set 8 | demyanovo
# Processing Record 16 of Set 8 | moose factory
# Processing Record 17 of Set 8 | pudozh
# Processing Record 18 of Set 8 | botucatu
# Processing Record 19 of Set 8 | high rock
# Processing Record 20 of Set 8 | calama
# Processing Record 21 of Set 8 | acari
# Processing Record 22 of Set 8 | loikaw
# Processing Record 23 of Set 8 | pyaozerskiy
# Processing Record 24 of Set 8 | soyo
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | uthal
# Processing Record 27 of Set 8 | coquimbo
# Processing Record 28 of Set 8 | kehychivka
# Processing Record 29 of Set 8 | thonon-les-bains
# Processing Record 30 of Set 8 | porosozero
# Processing Record 31 of Set 8 | mount gambier
# Processing Record 32 of Set 8 | katherine
# Processing Record 33 of Set 8 | khani
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 8 | road town
# Processing Record 37 of Set 8 | uetze
# Processing Record 38 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 8 | mandali
# Processing Record 40 of Set 8 | zaysan
# Processing Record 41 of Set 8 | porto santo
# Processing Record 42 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 43 of Set 8 | goderich
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | acapulco
# Processing Record 46 of Set 8 | mecca
# Processing Record 47 of Set 8 | ostrovnoy
# Processing Record 48 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 8 | roebourne
# Processing Record 50 of Set 8 | palasa
# Processing Record 1 of Set 9 | bonavista
# Processing Record 2 of Set 9 | santo domingo
# Processing Record 3 of Set 9 | lere
# Processing Record 4 of Set 9 | santa cruz de la palma
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | gamba
# Processing Record 7 of Set 9 | espanola
# Processing Record 8 of Set 9 | souillac
# Processing Record 9 of Set 9 | isla mujeres
# Processing Record 10 of Set 9 | muisne
# Processing Record 11 of Set 9 | eureka
# Processing Record 12 of Set 9 | yarmouth
# Processing Record 13 of Set 9 | nizwa
# Processing Record 14 of Set 9 | kristiinankaupunki
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | stepnyak
# Processing Record 18 of Set 9 | ust-ilimsk
# Processing Record 19 of Set 9 | maxixe
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | winslow
# Processing Record 22 of Set 9 | san ramon
# Processing Record 23 of Set 9 | asau
# Processing Record 24 of Set 9 | masumbwe
# Processing Record 25 of Set 9 | juba
# Processing Record 26 of Set 9 | olafsvik
# Processing Record 27 of Set 9 | srandakan
# Processing Record 28 of Set 9 | aklavik
# Processing Record 29 of Set 9 | malkapur
# Processing Record 30 of Set 9 | palmer
# Processing Record 31 of Set 9 | kumta
# Processing Record 32 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | cabo san lucas
# Processing Record 35 of Set 9 | vuktyl
# Processing Record 36 of Set 9 | krasnoselkup
# Processing Record 37 of Set 9 | alugan
# Processing Record 38 of Set 9 | bitung
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | scarborough
# Processing Record 41 of Set 9 | la rioja
# Processing Record 42 of Set 9 | katangli
# Processing Record 43 of Set 9 | sibolga
# Processing Record 44 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 9 | cao bang
# Processing Record 46 of Set 9 | srednekolymsk
# Processing Record 47 of Set 9 | namibe
# Processing Record 48 of Set 9 | ballina
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | college
# Processing Record 2 of Set 10 | maragogi
# Processing Record 3 of Set 10 | ourem
# Processing Record 4 of Set 10 | bongandanga
# Processing Record 5 of Set 10 | diffa
# Processing Record 6 of Set 10 | broken hill
# Processing Record 7 of Set 10 | moree
# Processing Record 8 of Set 10 | key west
# Processing Record 9 of Set 10 | yenagoa
# Processing Record 10 of Set 10 | coahuayana
# Processing Record 11 of Set 10 | ayios matthaios
# City not found. Skipping...
# Processing Record 12 of Set 10 | buta
# Processing Record 13 of Set 10 | brae
# Processing Record 14 of Set 10 | montbeliard
# Processing Record 15 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 16 of Set 10 | nelson bay
# Processing Record 17 of Set 10 | nouadhibou
# Processing Record 18 of Set 10 | brazzaville
# Processing Record 19 of Set 10 | griffith
# Processing Record 20 of Set 10 | raudeberg
# Processing Record 21 of Set 10 | san clemente
# Processing Record 22 of Set 10 | kurumkan
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | avera
# Processing Record 25 of Set 10 | sungaipenuh
# Processing Record 26 of Set 10 | balkhash
# Processing Record 27 of Set 10 | thinadhoo
# Processing Record 28 of Set 10 | baruun-urt
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | oppdal
# Processing Record 31 of Set 10 | luwuk
# Processing Record 32 of Set 10 | syamzha
# Processing Record 33 of Set 10 | rovaniemi
# Processing Record 34 of Set 10 | pokhara
# Processing Record 35 of Set 10 | loandjili
# Processing Record 36 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 37 of Set 10 | boke
# Processing Record 38 of Set 10 | petrolina
# Processing Record 39 of Set 10 | iskateley
# Processing Record 40 of Set 10 | goundam
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | itaberai
# Processing Record 43 of Set 10 | zhigansk
# Processing Record 44 of Set 10 | saldanha
# Processing Record 45 of Set 10 | wangqing
# Processing Record 46 of Set 10 | seymchan
# Processing Record 47 of Set 10 | port hedland
# Processing Record 48 of Set 10 | ossora
# Processing Record 49 of Set 10 | lerik
# Processing Record 50 of Set 10 | itaituba
# Processing Record 1 of Set 11 | ylojarvi
# Processing Record 2 of Set 11 | sao francisco do sul
# Processing Record 3 of Set 11 | paragominas
# Processing Record 4 of Set 11 | muli
# Processing Record 5 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 11 | bengkulu
# Processing Record 7 of Set 11 | ryotsu
# Processing Record 8 of Set 11 | daru
# Processing Record 9 of Set 11 | laguna
# Processing Record 10 of Set 11 | narsaq
# Processing Record 11 of Set 11 | santa fe
# Processing Record 12 of Set 11 | cockburn town
# Processing Record 13 of Set 11 | mansa
# Processing Record 14 of Set 11 | stjordalshalsen
# Processing Record 15 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 16 of Set 11 | makambako
# Processing Record 17 of Set 11 | alice springs
# Processing Record 18 of Set 11 | seoul
# Processing Record 19 of Set 11 | ilo
# Processing Record 20 of Set 11 | tazovskiy
# Processing Record 21 of Set 11 | giaveno
# Processing Record 22 of Set 11 | gua musang
# Processing Record 23 of Set 11 | grammenitsa
# Processing Record 24 of Set 11 | san-pedro
# Processing Record 25 of Set 11 | tautira
# Processing Record 26 of Set 11 | golkoy
# Processing Record 27 of Set 11 | oktyabrskiy
# Processing Record 28 of Set 11 | sechura
# Processing Record 29 of Set 11 | mokhsogollokh
# Processing Record 30 of Set 11 | taoudenni
# Processing Record 31 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 32 of Set 11 | tangzhai
# Processing Record 33 of Set 11 | palm bay
# Processing Record 34 of Set 11 | atikokan
# Processing Record 35 of Set 11 | cowra
# Processing Record 36 of Set 11 | gogrial
# Processing Record 37 of Set 11 | antofagasta
# Processing Record 38 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 11 | shubarkuduk
# Processing Record 40 of Set 11 | spas-demensk
# Processing Record 41 of Set 11 | disna
# Processing Record 42 of Set 11 | maniwaki
# Processing Record 43 of Set 11 | balgazyn
# Processing Record 44 of Set 11 | tinjah
# City not found. Skipping...
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | darnah
# Processing Record 47 of Set 11 | tessalit
# Processing Record 48 of Set 11 | chake chake
# Processing Record 49 of Set 11 | sterling
# Processing Record 50 of Set 11 | aljezur
# Processing Record 1 of Set 12 | harper
# Processing Record 2 of Set 12 | katubao
# Processing Record 3 of Set 12 | launceston
# Processing Record 4 of Set 12 | abnub
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | jackson
# Processing Record 7 of Set 12 | kondoa
# Processing Record 8 of Set 12 | cheremshan
# Processing Record 9 of Set 12 | udachnyy
# Processing Record 10 of Set 12 | dubbo
# Processing Record 11 of Set 12 | chicama
# Processing Record 12 of Set 12 | lebanon
# Processing Record 13 of Set 12 | kajaani
# Processing Record 14 of Set 12 | sakakah
# Processing Record 15 of Set 12 | talcahuano
# Processing Record 16 of Set 12 | dordrecht
# Processing Record 17 of Set 12 | penzance
# Processing Record 18 of Set 12 | bathsheba
# Processing Record 19 of Set 12 | olga
# Processing Record 20 of Set 12 | leninskoye
# Processing Record 21 of Set 12 | aqtobe
# Processing Record 22 of Set 12 | ahipara
# Processing Record 23 of Set 12 | ko samui
# Processing Record 24 of Set 12 | fenoarivo
# Processing Record 25 of Set 12 | karpathos
# Processing Record 26 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 27 of Set 12 | tecoanapa
# Processing Record 28 of Set 12 | anadyr
# Processing Record 29 of Set 12 | biak
# Processing Record 30 of Set 12 | klyuchi
# Processing Record 31 of Set 12 | khandyga
# Processing Record 32 of Set 12 | kandry
# Processing Record 33 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 12 | acobamba
# Processing Record 36 of Set 12 | sorland
# Processing Record 37 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 12 | oriximina
# Processing Record 39 of Set 12 | abeokuta
# Processing Record 40 of Set 12 | san matias
# Processing Record 41 of Set 12 | lima
# Processing Record 42 of Set 12 | brejo santo
# Processing Record 43 of Set 12 | valparaiso
# Processing Record 44 of Set 12 | sibu
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | tevriz
# Processing Record 47 of Set 12 | eregli
# Processing Record 48 of Set 12 | ketchikan
# Processing Record 49 of Set 12 | saryozek
# Processing Record 50 of Set 12 | phan thiet
# Processing Record 1 of Set 13 | kenora
# Processing Record 2 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 13 | makakilo city
# Processing Record 5 of Set 13 | aboso
# Processing Record 6 of Set 13 | umm lajj
# Processing Record 7 of Set 13 | tsentralnyy
# City not found. Skipping...
# Processing Record 8 of Set 13 | along
# Processing Record 9 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 10 of Set 13 | ampanihy
# Processing Record 11 of Set 13 | ronne
# Processing Record 12 of Set 13 | khudumelapye
# Processing Record 13 of Set 13 | emerald
# Processing Record 14 of Set 13 | barabinsk
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | srikakulam
# Processing Record 17 of Set 13 | vostok
# Processing Record 18 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 19 of Set 13 | verkhovazhye
# Processing Record 20 of Set 13 | vestmannaeyjar
# Processing Record 21 of Set 13 | kristiansund
# Processing Record 22 of Set 13 | tandil
# Processing Record 23 of Set 13 | mangan
# Processing Record 24 of Set 13 | porto novo
# Processing Record 25 of Set 13 | kolda
# Processing Record 26 of Set 13 | rapid valley
# Processing Record 27 of Set 13 | tumut
# Processing Record 28 of Set 13 | esperance
# Processing Record 29 of Set 13 | atar
# Processing Record 30 of Set 13 | roatan
# Processing Record 31 of Set 13 | carutapera
# Processing Record 32 of Set 13 | oranjestad
# Processing Record 33 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 13 | falefa
# Processing Record 35 of Set 13 | puerto escondido
# Processing Record 36 of Set 13 | novyy urgal
# Processing Record 37 of Set 13 | thabazimbi
# Processing Record 38 of Set 13 | ermelo
# Processing Record 39 of Set 13 | broome
# Processing Record 40 of Set 13 | fairbanks
# Processing Record 41 of Set 13 | bontang
# Processing Record 42 of Set 13 | midwest city
# Processing Record 43 of Set 13 | skibotn
# Processing Record 44 of Set 13 | beloha
# Processing Record 45 of Set 13 | puerto colombia
# Processing Record 46 of Set 13 | crixas
# Processing Record 47 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 13 | mehamn
# Processing Record 49 of Set 13 | muncar
# Processing Record 50 of Set 13 | urumqi
# Processing Record 1 of Set 14 | kitimat
# Processing Record 2 of Set 14 | tabou
# Processing Record 3 of Set 14 | tutayev
# Processing Record 4 of Set 14 | scottsbluff
# Processing Record 5 of Set 14 | aberdeen
# Processing Record 6 of Set 14 | miyako
# Processing Record 7 of Set 14 | mao
# Processing Record 8 of Set 14 | sao gabriel da cachoeira
# Processing Record 9 of Set 14 | nishihara
# Processing Record 10 of Set 14 | bairnsdale
# Processing Record 11 of Set 14 | naantali
# Processing Record 12 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 14 | westport
# Processing Record 14 of Set 14 | sola
# Processing Record 15 of Set 14 | boissevain
# Processing Record 16 of Set 14 | tala
# Processing Record 17 of Set 14 | glenwood springs
# Processing Record 18 of Set 14 | le vauclin
# Processing Record 19 of Set 14 | medea
# Processing Record 20 of Set 14 | shimoda
# Processing Record 21 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 22 of Set 14 | galveston
# Processing Record 23 of Set 14 | kranuan
# Processing Record 24 of Set 14 | dingle
# Processing Record 25 of Set 14 | caico
# Processing Record 26 of Set 14 | sioux lookout
# Processing Record 27 of Set 14 | brownsville
# Processing Record 28 of Set 14 | weymouth
# Processing Record 29 of Set 14 | kouango
# Processing Record 30 of Set 14 | ittiri
# Processing Record 31 of Set 14 | dom pedrito
# Processing Record 32 of Set 14 | constantine
# Processing Record 33 of Set 14 | flinders
# Processing Record 34 of Set 14 | los llanos de aridane
# Processing Record 35 of Set 14 | kalach-na-donu
# Processing Record 36 of Set 14 | kurchum
# Processing Record 37 of Set 14 | sinnamary
# Processing Record 38 of Set 14 | sovetskiy
# Processing Record 39 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 14 | saint-georges
# Processing Record 41 of Set 14 | dwarka
# Processing Record 42 of Set 14 | honggang
# Processing Record 43 of Set 14 | mettet
# Processing Record 44 of Set 14 | tongliao
# Processing Record 45 of Set 14 | northam
# Processing Record 46 of Set 14 | santa lucia
# Processing Record 47 of Set 14 | balkanabat
# Processing Record 48 of Set 14 | port augusta
# Processing Record 49 of Set 14 | harnosand
# Processing Record 50 of Set 14 | qandala
# Processing Record 1 of Set 15 | purpe
# Processing Record 2 of Set 15 | yarensk
# Processing Record 3 of Set 15 | kiunga
# Processing Record 4 of Set 15 | labuan
# Processing Record 5 of Set 15 | ipora
# Processing Record 6 of Set 15 | codajas
# Processing Record 7 of Set 15 | westlock
# Processing Record 8 of Set 15 | skibbereen
# Processing Record 9 of Set 15 | dunedin
# Processing Record 10 of Set 15 | cisarua
# Processing Record 11 of Set 15 | quelimane
# Processing Record 12 of Set 15 | madras
# Processing Record 13 of Set 15 | xinxiang
# Processing Record 14 of Set 15 | babstovo
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | takoradi
# Processing Record 17 of Set 15 | bagan
# Processing Record 18 of Set 15 | zhitnevo
# Processing Record 19 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 15 | tulun
# Processing Record 21 of Set 15 | nilokheri
# Processing Record 22 of Set 15 | korsakov
# Processing Record 23 of Set 15 | kodinsk
# Processing Record 24 of Set 15 | kleive
# Processing Record 25 of Set 15 | gunjur
# Processing Record 26 of Set 15 | batemans bay
# Processing Record 27 of Set 15 | sulangan
# Processing Record 28 of Set 15 | tuy hoa
# Processing Record 29 of Set 15 | katha
# City not found. Skipping...
# Processing Record 30 of Set 15 | kismayo
# Processing Record 31 of Set 15 | saryg-sep
# Processing Record 32 of Set 15 | salalah
# Processing Record 33 of Set 15 | anjiang
# Processing Record 34 of Set 15 | muravlenko
# Processing Record 35 of Set 15 | abu samrah
# Processing Record 36 of Set 15 | dembi dolo
# Processing Record 37 of Set 15 | dicabisagan
# Processing Record 38 of Set 15 | caravelas
# Processing Record 39 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 15 | dongsheng
# Processing Record 41 of Set 15 | angoram
# Processing Record 42 of Set 15 | lexington
# Processing Record 43 of Set 15 | nipawin
# Processing Record 44 of Set 15 | jalor
# Processing Record 45 of Set 15 | buchanan
# Processing Record 46 of Set 15 | vrangel
# Processing Record 47 of Set 15 | perleberg
# Processing Record 48 of Set 15 | hukuntsi
# Processing Record 49 of Set 15 | muroto
# Processing Record 50 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 16 | luancheng
# Processing Record 2 of Set 16 | cayenne
# Processing Record 3 of Set 16 | saurimo
# Processing Record 4 of Set 16 | rorvik
# Processing Record 5 of Set 16 | lumberton
# Processing Record 6 of Set 16 | lingyuan
# Processing Record 7 of Set 16 | waipawa
# Processing Record 8 of Set 16 | grand-lahou
# Processing Record 9 of Set 16 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Mahebourg -20.4081   57.7000     71.26        83          20        0.00
# 1      Kodiak  57.7900 -152.4072     38.71        81         100       19.57
# 2   Egvekinot  66.3167 -179.1667     15.35        93         100        4.43
# 3       Vaini -21.2000 -175.2000     78.96        89          75        8.05
# 4     Aguilas  37.4063   -1.5829     65.77        63          53        5.28
# 5     Ushuaia -54.8000  -68.3000     40.66        65          40       18.41
# 6    Luderitz -26.6481   15.1594     57.31        80           5       13.89
# 7  Khalilabad  26.7750   83.0736     70.97        71           0        2.75
# 8     Rikitea -23.1203 -134.9692     73.45        85         100        9.26
# 9        Fare -16.7000 -151.0167     79.25        77         100       14.92
#
#   Country Current Description
# 0      MU          few clouds
# 1      US          light rain
# 2      RU     overcast clouds
# 3      TO       broken clouds
# 4      ES       broken clouds
# 5      AR    scattered clouds
# 6      NA           clear sky
# 7      IN           clear sky
# 8      PF     overcast clouds
# 9      PF          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df  = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mahebourg      MU -20.4081   57.7000     71.26        83          20
# 1      Kodiak      US  57.7900 -152.4072     38.71        81         100
# 2   Egvekinot      RU  66.3167 -179.1667     15.35        93         100
# 3       Vaini      TO -21.2000 -175.2000     78.96        89          75
# 4     Aguilas      ES  37.4063   -1.5829     65.77        63          53
# 5     Ushuaia      AR -54.8000  -68.3000     40.66        65          40
# 6    Luderitz      NA -26.6481   15.1594     57.31        80           5
# 7  Khalilabad      IN  26.7750   83.0736     70.97        71           0
# 8     Rikitea      PF -23.1203 -134.9692     73.45        85         100
# 9        Fare      PF -16.7000 -151.0167     79.25        77         100
#
#    Wind Speed Current Description
# 0        0.00          few clouds
# 1       19.57          light rain
# 2        4.43     overcast clouds
# 3        8.05       broken clouds
# 4        5.28       broken clouds
# 5       18.41    scattered clouds
# 6       13.89           clear sky
# 7        2.75           clear sky
# 8        9.26     overcast clouds
# 9       14.92          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
